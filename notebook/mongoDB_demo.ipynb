# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "vechical insurance data"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://shindeprajwal237_db_user:ET5gpmBm6POGv6uF@cluster0.muz3rym.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# NXDOMAIN                                  Traceback (most recent call last)
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:108, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#     107 try:
# --> 108     results = _resolve(
#     109         "_" + self.__srv + "._tcp." + self.__fqdn, "SRV", lifetime=self.__connect_timeout
#     110     )
#     111 except Exception as exc:
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:53, in _resolve(*args, **kwargs)
#      51     from dns import resolver
# ---> 53     return resolver.resolve(*args, **kwargs)
#      54 else:
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\dns\resolver.py:1572, in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1563 """Query nameservers to find the answer to the question.
#    1564
#    1565 This is a convenience function that uses the default resolver
#    (...)   1569 parameters.
#    1570 """
# -> 1572 return get_default_resolver().resolve(
#    1573     qname,
#    1574     rdtype,
#    1575     rdclass,
#    1576     tcp,
#    1577     source,
#    1578     raise_on_no_answer,
#    1579     source_port,
#    1580     lifetime,
#    1581     search,
#    1582 )
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\dns\resolver.py:1314, in Resolver.resolve(self, qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1313 while True:
# -> 1314     (request, answer) = resolution.next_request()
#    1315     # Note we need to say "if answer is not None" and not just
#    1316     # "if answer" because answer implements __len__, and python
#    1317     # will call that.  We want to return if we have an answer
#    1318     # object, including in cases where its length is 0.
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\dns\resolver.py:758, in _Resolution.next_request(self)
#     753 #
#     754 # We've tried everything and only gotten NXDOMAINs.  (We know
#     755 # it's only NXDOMAINs as anything else would have returned
#     756 # before now.)
#     757 #
# --> 758 raise NXDOMAIN(qnames=self.qnames_to_try, responses=self.nxdomain_responses)
#
# NXDOMAIN: The DNS query name does not exist: _mongodb._tcp.cluster0.0aygk.mongodb.net.
#
# The above exception was the direct cause of the following exception:
#
# ConfigurationError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 client = pymongo.MongoClient(CONNECTION_URL)
#       2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:908, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     905     self._init_background()
#     907 if _IS_SYNC and connect:
# --> 908     self._get_topology()
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1776, in MongoClient._get_topology(self)
#    1774 if not self._opened:
#    1775     if self._resolve_srv_info["is_srv"]:
# -> 1776         self._resolve_srv()
#    1777         self._init_background()
#    1778     self._topology.open()
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:927, in MongoClient._resolve_srv(self)
#     923 if timeout is not None:
#     924     timeout = common.validate_timeout_or_none_or_zero(
#     925         keyword_opts.cased_key("connecttimeoutms"), timeout
#     926     )
# --> 927 res = uri_parser._parse_srv(
#     928     entity,
#     929     self._port,
#     930     validate=True,
#     931     warn=True,
#     932     normalize=False,
#     933     connect_timeout=timeout,
#     934     srv_service_name=srv_service_name,
#     935     srv_max_hosts=srv_max_hosts,
#     936 )
#     937 seeds.update(res["nodelist"])
#     938 opts = res["options"]
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\uri_parser.py:168, in _parse_srv(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     166 connect_timeout = connect_timeout or options.get("connectTimeoutMS")
#     167 dns_resolver = _SrvResolver(fqdn, connect_timeout, srv_service_name, srv_max_hosts)
# --> 168 nodes = dns_resolver.get_hosts()
#     169 dns_options = dns_resolver.get_options()
#     170 if dns_options:
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:148, in _SrvResolver.get_hosts(self)
#     147 def get_hosts(self) -> list[tuple[str, Any]]:
# --> 148     _, nodes = self._get_srv_response_and_hosts(True)
#     149     return nodes
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:122, in _SrvResolver._get_srv_response_and_hosts(self, encapsulate_errors)
#     119 def _get_srv_response_and_hosts(
#     120     self, encapsulate_errors: bool
#     121 ) -> tuple[resolver.Answer, list[tuple[str, Any]]]:
# --> 122     results = self._resolve_uri(encapsulate_errors)
#     124     # Construct address tuples
#     125     nodes = [
#     126         (maybe_decode(res.target.to_text(omit_final_dot=True)), res.port)  # type: ignore[attr-defined]
#     127         for res in results
#     128     ]
#
# File c:\Projects\mlops-vehicle-insurance-\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:116, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#     114         raise
#     115     # Else, raise all errors as ConfigurationError.
# --> 116     raise ConfigurationError(str(exc)) from exc
#     117 return results
#
# ConfigurationError: The DNS query name does not exist: _mongodb._tcp.cluster0.0aygk.mongodb.net.
